# %% [markdown]
# # DL_101: NN Introduction

# %% [markdown]
# ## Influence of Weights and Bias on the Shape of the Activation Functions
#
# For Questions on this Exercise: anmuel@ethz.ch

# %%
# import libraries
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE" # prevents a restart of the kernel

import numpy as np
import tensorflow as tf 
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.activations import *
import matplotlib
import matplotlib.pyplot as plt

# %%
# define activation function
def relu(x):
    if x > 0:
        return x
    else: return 0
def sigmoid(x):
    return (1 / (1 + np.exp(-x)))
def tanh(x):
    return np.tanh(x)

# %%
# define Weight and Bias for the Layer (try out different variatios)
w1 = +2
b1 = +2
# choose activation function
act = relu

x = np.linspace(start=-10, stop=10, num=1000)
y = np.array([act(xi * 1 + 0) for xi in x])
y_act = np.array([act(xi * w1 + b1) for xi in x])

# %%
plt.figure(figsize=(7,7))
plt.xlim(-10,10)
plt.ylim(-5,15)

plt.plot(x, y, color="red", label="default activation function")
plt.plot(x, y_act, color="blue", label="with activation function")
plt.legend()
plt.grid(True)
plt.show()

# %%
# define Weight and Bias for the Output
w2 = 1
b2 = -5
y_out = np.array([(xi * w2 + b2) for xi in y_act])

# %%
plt.figure(figsize=(7,7))
plt.grid(True)
plt.plot(x, y_act, color="blue", label="with activation function")
plt.plot(x, y_out, color="green", label="output")
plt.legend()
plt.show()

# %% [markdown]
# ## Influence of the Activation Functions on the Prediction Performance

# %%
# Define random Problem
def f(x):
    return x**4 + -5*x**3 + 14*x**2 + x + 10
x = np.linspace(start=-10.0, stop=10.0, num=2000).reshape(-1, 1)
y = f(x)

# %%
model = Sequential()
model.add(Dense(200)) # Input zu Hidden
model.add(Dense(200)) # Input zu Hidden
model.add(Dense(1)) # Vom Hidden zum Output
model.compile(optimizer=Adam(learning_rate=1e-2), loss="mse")
model.fit(x, y, epochs=30)
y_pred_linear = model.predict(x)
# Out:
# C:\Users\anmuel\AppData\Local\anaconda3\envs\tensorflow\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/30
# 63/63 [==============================] - 3s 7ms/step - loss: 14354105.0000
# Epoch 2/30
# 63/63 [==============================] - 0s 5ms/step - loss: 10152844.0000
# Epoch 3/30
# 63/63 [==============================] - 0s 5ms/step - loss: 10060893.0000
# Epoch 4/30
# 63/63 [==============================] - 0s 7ms/step - loss: 10331819.0000
# Epoch 5/30
# 63/63 [==============================] - 1s 8ms/step - loss: 10198704.0000
# Epoch 6/30
# 63/63 [==============================] - 0s 7ms/step - loss: 10197751.0000
# Epoch 7/30
# 63/63 [==============================] - 0s 7ms/step - loss: 10154725.0000
# Epoch 8/30
# 63/63 [==============================] - 1s 9ms/step - loss: 10251342.0000
# Epoch 9/30
# 63/63 [==============================] - 0s 7ms/step - loss: 10114613.0000
# Epoch 10/30
# 63/63 [==============================] - 0s 6ms/step - loss: 10161217.0000
# Epoch 11/30
# 63/63 [==============================] - 0s 6ms/step - loss: 10135493.0000
# Epoch 12/30
# 63/63 [==============================] - 0s 5ms/step - loss: 10112352.0000
# Epoch 13/30
# 63/63 [==============================] - 0s 6ms/step - loss: 10198655.0000
# Epoch 14/30
# 63/63 [==============================] - 0s 7ms/step - loss: 10225014.0000
# Epoch 15/30
# 63/63 [==============================] - 0s 7ms/step - loss: 10226088.0000
# Epoch 16/30
# 63/63 [==============================] - 0s 5ms/step - loss: 10140061.0000
# Epoch 17/30
# 63/63 [==============================] - 0s 5ms/step - loss: 10297767.0000
# Epoch 18/30
# 63/63 [==============================] - 0s 5ms/step - loss: 10172593.0000
# Epoch 19/30
# 63/63 [==============================] - 0s 6ms/step - loss: 10291443.0000
# Epoch 20/30
# 63/63 [==============================] - 0s 5ms/step - loss: 10211053.0000
# Epoch 21/30
# 63/63 [==============================] - 0s 4ms/step - loss: 10173970.0000
# Epoch 22/30
# 63/63 [==============================] - 0s 4ms/step - loss: 10248661.0000
# Epoch 23/30
# 63/63 [==============================] - 0s 4ms/step - loss: 10207277.0000
# Epoch 24/30
# 63/63 [==============================] - 0s 4ms/step - loss: 10133476.0000
# Epoch 25/30
# 63/63 [==============================] - 0s 5ms/step - loss: 
# 63/63 [==============================] - 1s 9ms/step - loss: 17952236.0000
# Epoch 3/30
# 63/63 [==============================] - 1s 9ms/step - loss: 17278032.0000
# Epoch 4/30
# 63/63 [==============================] - 1s 8ms/step - loss: 16675886.0000
# Epoch 5/30
# 63/63 [==============================] - 0s 8ms/step - loss: 16147296.0000
# Epoch 6/30
# 63/63 [==============================] - 0s 8ms/step - loss: 15677859.0000
# Epoch 7/30
# 63/63 [==============================] - 0s 7ms/step - loss: 15267038.0000
# Epoch 8/30
# 63/63 [==============================] - 0s 7ms/step - loss: 14909229.0000
# Epoch 9/30
# 63/63 [==============================] - 0s 7ms/step - loss: 14598230.0000
# Epoch 10/30
# 63/63 [==============================] - 1s 9ms/step - loss: 14328416.0000
# Epoch 11/30
# 63/63 [==============================] - 1s 9ms/step - loss: 14101075.0000
# Epoch 12/30
# 63/63 [==============================] - 1s 9ms/step - loss: 13906257.0000
# Epoch 13/30
# 63/63 [==============================] - 1s 8ms/step - loss: 13739510.0000
# Epoch 14/30
# 63/63 [==============================] - 0s 6ms/step - loss: 13602634.0000
# Epoch 15/30
# 63/63 [==============================] - 0s 6ms/step - loss: 13487129.0000
# Epoch 16/30
# 63/63 [==============================] - 1s 9ms/step - loss: 13392971.0000
# Epoch 17/30
# 63/63 [==============================] - 1s 10ms/step - loss: 13314928.0000
# Epoch 18/30
# 63/63 [==============================] - 1s 15ms/step - loss: 13251266.0000
# Epoch 19/30
# 63/63 [==============================] - 2s 27ms/step - loss: 13199964.0000
# Epoch 20/30
# 63/63 [==============================] - 1s 11ms/step - loss: 13157148.0000
# Epoch 21/30
# 63/63 [==============================] - 1s 10ms/step - loss: 13126015.0000
# Epoch 22/30
# 63/63 [==============================] - 1s 13ms/step - loss: 13100443.0000
# Epoch 23/30
# 63/63 [==============================] - 1s 12ms/step - loss: 13081232.0000
# Epoch 24/30
# 63/63 [==============================] - 1s 12ms/step - loss: 13064094.0000
# Epoch 25/30
# 63/63 [==============================] - 1s 9ms/step - loss: 13050917.0000
# Epoch 26/30
# 63/63 [==============================] - 0s 7ms/step - loss: 13042164.0000
# Epoch 27/30
# 63/63 [==============================] - 1s 8ms/step - loss: 13034669.0000
# Epoch 28/30
# 63/63 [==============================] - 1s 12ms/step - loss: 13030409.0000
# Epoch 29/30
# 63/63 [==============================] - 1s 9ms/step - loss: 13025581.0000
# Epoch 30/30
# 63/63 [==============================] - 1s 9ms/step - loss: 13024970.0000
# 63/63 [==============================] - 1s 4ms/step

# %%
model = Sequential()
model.add(Dense(500)) # Input to Hidden
model.add(Activation("relu")) # ReLU after Hidden
model.add(Dense(500)) # Input to Hidden
model.add(Activation("relu")) # ReLU after Hidden
model.add(Dense(1)) # From Hidden to Output
model.compile(optimizer=Adam(learning_rate=1e-2), loss="mse")
model.fit(x, y, epochs=30)
y_pred_relu = model.predict(x)

# %%
model = Sequential()
model.add(Dense(500)) # Input to Hidden
model.add(Activation("sigmoid")) # sigmoid after Hidden
#model.add(Activation("relu")) # ReLU vom Hidden
model.add(Dense(500)) # Input to Hidden
model.add(Activation("sigmoid")) # sigmoid after Hidden
model.add(Dense(1)) # From Hidden to Output
model.compile(optimizer=Adam(learning_rate=1e-2), loss="mse")
model.fit(x, y, epochs=30)
y_pred_sigmoid = model.predict(x)
# Out:
# Epoch 1/30
# 63/63 [==============================] -
# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(24,12))
ax1.plot(x, y, color="blue")
ax1.plot(x.flatten(), y_pred_linear.flatten(), color="red", label="linear")
ax1.grid(True)
ax1.legend()
ax2.plot(x, y, color="blue")
ax2.plot(x.flatten(), y_pred_sigmoid.flatten(), color="red", label="sigmoid")
ax2.grid(True)
ax2.legend()
ax3.plot(x, y, color="blue")
ax3.plot(x.flatten(), y_pred_relu.flatten(), color="red", label="relu")
ax3.grid(True)
ax3.legend()

# %% [markdown]
# ## Influence of the amount of neurons

# %%
# Define random artificial problem f(x)
def f(x):
    return x**2 + x + 10
x = np.linspace(start=-10, stop=+10, num=1000).reshape(-1,1)
y = f(x)

# %%
# Build simple sequential model
model = Sequential()
model.add(Dense(12))
model.add(Activation("relu")) # ReLU after Hidden
model.add(Dense(1)) # From Hidden to Output
model.compile(optimizer=Adam(learning_rate=5e-2), loss="mse")
model.fit(x, y, epochs=50)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 3ms/step - loss: 1762.9630
# Epoch 2/50
# 32/32 [==============================] - 0s 3ms/step - loss: 213.4981
# Epoch 3/50
# 32/32 [==============================] - 0s 4ms/step - loss: 87.2624
# Epoch 4/50
# 32/32 [==============================] - 0s 7ms/step - loss: 71.0107
# Epoch 5/50
# 32/32 [==============================] - 0s 4ms/step - loss: 57.7341
# Epoch 6/50
# 32/32 [==============================] - 0s 4ms/step - loss: 47.7338
# Epoch 7/50
# 32/32 [==============================] - 0s 5ms/step - loss: 38.4440
# Epoch 8/50
# 32/32 [==============================] - 0s 5ms/step - loss: 31.3691
# Epoch 9/50
# 32/32 [==============================] - 0s 4ms/step - loss: 26.1773
# Epoch 10/50
# 32/32 [==============================] - 0s 6ms/step - loss: 21.9483
# Epoch 11/50
# 32/32 [==============================] - 0s 5ms/step - loss: 18.4358
# Epoch 12/50
# 32/32 [==============================] - 0s 8ms/step - loss: 15.3427
# Epoch 13/50
# 32/32 [==============================] - 0s 6ms/step - loss: 13.2269
# Epoch 14/50
# 32/32 [==============================] - 0s 8ms/step - loss: 11.1134
# Epoch 15/50
# 32/32 [==============================] - 0s 7ms/step - loss: 9.7318
# Epoch 16/50
# 32/32 [==============================] - 0s 7ms/step - loss: 8.5749
# Epoch 17/50
# 32/32 [==============================] - 0s 6ms/step - loss: 7.3978
# Epoch 18/50
# 32/32 [==============================] - 0s 7ms/step - loss: 5.6800
# Epoch 19/50
# 32/32 [==============================] - 0s 8ms/step - loss: 4.5285
# Epoch 20/50
# 32/32 [==============================] - 0s 7ms/step - loss: 3.8900
# Epoch 21/50
# 32/32 [==============================] - 0s 6ms/step - loss: 3.1484
# Epoch 22/50
# 32/32 [==============================] - 0s 4ms/step - loss: 3.0684
# Epoch 23/50
# 32/32 [==============================] - 0s 4ms/step - loss: 2.4172
# Epoch 24/50
# 32/32 [==============================] - 0s 5ms/step - loss: 1.7146
# Epoch 25/50
# 32/32 [==============================] - 0s 6ms/step - loss: 1.5164
# Epoch 26/50
# 32/32 [==============================] - 0s 5ms/step - loss: 1.5304
# Epoch 27/50
# 32/32 [==============================] - 0s 5ms/step - loss: 1.2146
# Epoch 28/50
# 32/32 [==============================] - 0s 6ms/step - loss: 1.3155
# Epoch 29/50
# 32/32 [==============================] - 0s 5ms/step - loss: 1.5824
# Epoch 30/50
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0858
# Epoch 31/50
# 32/32 [==============================] - 0s 6ms/step - loss: 1.1282
# Epoch 32/50
# 32/32 [==============================] - 0s 5ms/step - loss: 1.6803
# Epoch 33/50
# 32/32 [==============================] - 0s 6ms/step - loss: 1.5745
# Epoch 34/50
# 32/32 [==============================] - 0s 5ms/step - loss: 1.1241
# Epoch 35/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.9438
# Epoch 36/50
# 32/32 [==============================] - 0s 7ms/step - loss: 0.9379
# Epoch 37/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9604
# Epoch 38/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9293
# Epoch 39/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9300
# Epoch 40/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9534
# Epoch 41/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9332
# Epoch 42/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9568
# Epoch 43/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9204
# Epoch 44/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.8999
# Epoch 45/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9646
# Epoch 46/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.9742
# Epoch 47/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0589
# Epoch 48/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8565
# Epoch 49/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8945
# Epoch 50/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.8326

# %%
W, b = model.layers[0].get_weights()
W2, b2 = model.layers[2].get_weights()
W, b, W2, b2 = W.flatten(), b.flatten(), W2.flatten(), b2.flatten()

# %%
for i in range (1, len(W)+1):
    y_hidden = np.array([W[:i] * xi + b[:i] for xi in x])
    y_relu = np.array([[relu(yhi) for yhi in yh] for yh in y_hidden])
    y_output = np.array([np.dot(W2[:i], yri) + b2 for yri in y_relu])
 
    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,5))
    ax1.grid(True)
    ax1.plot(x, y, color="k", linewidth=1.2, label="f(x)")
    ax1.plot(x.flatten(), y_output.flatten(), color="red", linewidth=1.2, label=str(i))
    ax1.legend()
    ax2.plot(x, y_relu.T[-1])
    ax2.grid(True)
    ax1.title.set_text("Num. Neurons: " + str(i))
    ax2.title.set_text("Contribution")
